# %% [markdown]
# #Dimensionality Reduction
# <h2> Demo 3: Implementing Common Techniques of Dimensionality Reduction  </h2>

# %% [markdown]
# ### Step 1: Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2: Load cancer.csv file

# %%
cancer = pd.read_csv('cancer.csv')
cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
cancer.shape
# Out:
# (569, 33)

# %%
cancer.diagnosis = cancer.diagnosis.map({'M':1 , 'B':0})

# %%
#Here we are dropping two columns i.e.diagnosis & id
x = cancer.drop(['diagnosis','id'], axis=1)
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  Unnamed: 32
# 0          0.4601                  0.11890          NaN
# 1          0.2750                  0.08902          NaN
# 2          0.3613                  0.08758          NaN
# 3          0.6638                  0.17300          NaN
# 4          0.2364                  0.07678          NaN
#
# [5 rows x 31 columns]

# %%
#Here we are saving target column i.e.diagnonis separately 
y = cancer.diagnosis
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
x.shape
# Out:
# (569, 31)

# %% [markdown]
# # Missing Value Ratio

# %%
x.isnull().sum()*100/len(x)
# Out:
# radius_mean                  0.0
# texture_mean                 0.0
# perimeter_mean               0.0
# area_mean                    0.0
# smoothness_mean              0.0
# compactness_mean             0.0
# concavity_mean               0.0
# concave points_mean          0.0
# symmetry_mean                0.0
# fractal_dimension_mean       0.0
# radius_se                    0.0
# texture_se                   0.0
# perimeter_se                 0.0
# area_se                      0.0
# smoothness_se                0.0
# compactness_se               0.0
# concavity_se                 0.0
# concave points_se            0.0
# symmetry_se                  0.0
# fractal_dimension_se         0.0
# radius_worst                 0.0
# texture_worst                0.0
# perimeter_worst              0.0
# area_worst                   0.0
# smoothness_worst             0.0
# compactness_worst            0.0
# concavity_worst              0.0
# concave points_worst         0.0
# symmetry_worst               0.0
# fractal_dimension_worst      0.0
# Unnamed: 32                100.0
# dtype: float64

# %%
x = x.drop(['Unnamed: 32'], axis=1)
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
x.shape
# Out:
# (569, 30)

# %%
x_orig = x.copy()

# %% [markdown]
# # Low Variance Filter

# %%
x.var()
# Out:
# radius_mean                    12.418920
# texture_mean                   18.498909
# perimeter_mean                590.440480
# area_mean                  123843.554318
# smoothness_mean                 0.000198
# compactness_mean                0.002789
# concavity_mean                  0.006355
# concave points_mean             0.001506
# symmetry_mean                   0.000752
# fractal_dimension_mean          0.000050
# radius_se                       0.076902
# texture_se                      0.304316
# perimeter_se                    4.087896
# area_se                      2069.431583
# smoothness_se                   0.000009
# compactness_se                  0.000321
# concavity_se                    0.000911
# concave points_se               0.000038
# symmetry_se                     0.000068
# fractal_dimension_se            0.000007
# radius_worst                   23.360224
# texture_worst                  37.776483
# perimeter_worst              1129.130847
# area_worst                 324167.385102
# smoothness_worst                0.000521
# compactness_worst               0.024755
# concavity_worst                 0.043524
# concave points_worst            0.004321
# symmetry_worst                  0.003828
# fractal_dimension_worst         0.000326
# dtype: float64

# %%
x_v = x/x.mean()
x_v.var()
# Out:
# radius_mean                0.062225
# texture_mean               0.049716
# perimeter_mean             0.069806
# area_mean                  0.288761
# smoothness_mean            0.021302
# compactness_mean           0.256193
# concavity_mean             0.805960
# concave points_mean        0.629172
# symmetry_mean              0.022899
# fractal_dimension_mean     0.012641
# radius_se                  0.468447
# texture_se                 0.205517
# perimeter_se               0.497656
# area_se                    1.271868
# smoothness_se              0.181847
# compactness_se             0.494046
# concavity_se               0.895783
# concave points_se          0.273609
# symmetry_se                0.161932
# fractal_dimension_se       0.486185
# radius_worst               0.088256
# texture_worst              0.057296
# perimeter_worst            0.098143
# area_worst                 0.418050
# smoothness_worst           0.029753
# compactness_worst          0.382900
# concavity_worst            0.587476
# concave points_worst       0.328959
# symmetry_worst             0.045489
# fractal_dimension_worst    0.046291
# dtype: float64

# %%
x_v.var()>0.03
# Out:
# radius_mean                 True
# texture_mean                True
# perimeter_mean              True
# area_mean                   True
# smoothness_mean            False
# compactness_mean            True
# concavity_mean              True
# concave points_mean         True
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                   True
# texture_se                  True
# perimeter_se                True
# area_se                     True
# smoothness_se               True
# compactness_se              True
# concavity_se                True
# concave points_se           True
# symmetry_se                 True
# fractal_dimension_se        True
# radius_worst                True
# texture_worst               True
# perimeter_worst             True
# area_worst                  True
# smoothness_worst           False
# compactness_worst           True
# concavity_worst             True
# concave points_worst        True
# symmetry_worst              True
# fractal_dimension_worst     True
# dtype: bool

# %%
x = x.loc[:,x_v.var()>0.03]
x.shape
# Out:
# (569, 26)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state = 29)
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
rf.feature_importances_
# Out:
# array([0.0573427 , 0.01754194, 0.03658484, 0.01788453, 0.01639014,
#        0.07256908, 0.1102909 , 0.01592384, 0.00613145, 0.01400035,
#        0.03802507, 0.00463479, 0.00485716, 0.00474858, 0.0036529 ,
#        0.00560437, 0.00665949, 0.10309074, 0.01883817, 0.14990177,
#        0.13195417, 0.01387423, 0.0361333 , 0.0911223 , 0.01630773,
#        0.00593544])

# %%
rf_feat = pd.Series(rf.feature_importances_, index= x_train.columns)
rf_feat
# Out:
# radius_mean                0.057343
# texture_mean               0.017542
# perimeter_mean             0.036585
# area_mean                  0.017885
# compactness_mean           0.016390
# concavity_mean             0.072569
# concave points_mean        0.110291
# radius_se                  0.015924
# texture_se                 0.006131
# perimeter_se               0.014000
# area_se                    0.038025
# smoothness_se              0.004635
# compactness_se             0.004857
# concavity_se               0.004749
# concave points_se          0.003653
# symmetry_se                0.005604
# fractal_dimension_se       0.006659
# radius_worst               0.103091
# texture_worst              0.018838
# perimeter_worst            0.149902
# area_worst                 0.131954
# compactness_worst          0.013874
# concavity_worst            0.036133
# concave points_worst       0.091122
# symmetry_worst             0.016308
# fractal_dimension_worst    0.005935
# dtype: float64

# %%
x = x.loc[:, rf_feat>0.01]
x.shape
# Out:
# (569, 18)

# %% [markdown]
# # High Correlation Filter

# %%
x_cor = x.corr()>0.95

# %%
x_cor
# Out:
#                       radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                  True         False            True       True
# texture_mean                False          True           False      False
# perimeter_mean               True         False            True       True
# area_mean                    True         False            True       True
# compactness_mean            False         False           False      False
# concavity_mean              False         False           False      False
# concave points_mean         False         False           False      False
# radius_se                   False         False           False      False
# perimeter_se                False         False           False      False
# area_se                     False         False           False      False
# radius_worst                 True         False            True       True
# texture_worst               False         False           False      False
# perimeter_worst              True         False            True       True
# area_worst                  False         False           False       True
# compactness_worst           False         False           False      False
# concavity_worst             False         False           False      False
# concave points_worst        False         False           False      False
# symmetry_worst              False         False           False      False
#
#                       compactness_mean  concavity_mean  concave points_mean  \
# radius_mean                      False           False                False
# texture_mean                     False           False                False
# perimeter_mean                   False           False                False
# area_mean                        False           False                False
# compactness_mean                  True           False                False
# concavity_mean                   False            True                False
# concave points_mean              False           False                 True
# radius_se                        False           False                False
# perimeter_se                     False           False                False
# area_se                          False           False                False
# radius_worst                     False           False                False
# texture_worst                    False           False                False
# perimeter_worst                  False           False                False
# area_worst                       False           False                False
# compactness_worst                False           False                False
# concavity_worst                  False           False                False
# concave points_worst             False           False                False
# symmetry_worst                   False           False                False
#
#                       radius_se  perimeter_se  area_se  radius_worst  \
# radius_mean               False         False    False          True
# texture_mean              False         False    False         False
# perimeter_mean            False         False    False          True
# area_mean                 False         False    False          True
# compactness_mean          False         False    False         False
# concavity_mean            False         False    False         False
# concave points_mean       False         False    False         False
# radius_se                  True          True     True         False
# perimeter_se               True          True    False         False
# area_se                    True         False     True         False
# radius_worst              False         False    False          True
# texture_worst             False         False    False         False
# perimeter_worst           False         False    False          True
# area_worst                False         False    False          True
# compactness_worst         False         False    False         False
# concavity_worst           False         False    False         False
# concave points_worst      False         False    False         False
# symmetry_worst            False         False    False         False
#
#                       texture_worst  perimeter_worst  area_worst  \
# radius_mean                   False             True       False
# texture_mean                  False            False       False
# perimeter_mean                False             True       False
# area_mean                     False             True        True
# compactness_mean              False            False       False
# concavity_mean                False            False       False
# concave points_mean           False            False       False
# radius_se                     False            False       False
# perimeter_se                  False            False       False
# area_se                       False            False       False
# radius_worst                  False             True        True
# texture_worst                  True            False       False
# perimeter_worst               False             True        True
# area_worst                    False             True        True
# compactness_worst             False            False       False
# concavity_worst               False            False       False
# concave points_worst          False            False       False
# symmetry_worst                False            False       False
#
#                       compactness_worst  concavity_worst  \
# radius_mean                       False            False
# texture_mean                      False            False
# perimeter_mean                    False            False
# area_mean                         False            False
# compactness_mean                  False            False
# concavity_mean                    False            False
# concave points_mean               False            False
# radius_se                         False            False
# perimeter_se                      False            False
# area_se                           False            False
# radius_worst                      False            False
# texture_worst                     False            False
# perimeter_worst                   False            False
# area_worst                        False            False
# compactness_worst                  True            False
# concavity_worst                   False             True
# concave points_worst              False            False
# symmetry_worst                    False            False
#
#                       concave points_worst  symmetry_worst
# radius_mean                          False           False
# texture_mean                         False           False
# perimeter_mean                       False           False
# area_mean                            False           False
# compactness_mean                     False           False
# concavity_mean                       False           False
# concave points_mean                  False           False
# radius_se                            False           False
# perimeter_se                         False           False
# area_se                              False           False
# radius_worst                         False           False
# texture_worst                        False           False
# perimeter_worst                      False           False
# area_worst                           False           False
# compactness_worst                    False           False
# concavity_worst                      False           False
# concave points_worst                  True           False
# symmetry_worst                       False            True

# %%
x_cor['radius_mean']
# Out:
# radius_mean              True
# texture_mean            False
# perimeter_mean           True
# area_mean                True
# compactness_mean        False
# concavity_mean          False
# concave points_mean     False
# radius_se               False
# perimeter_se            False
# area_se                 False
# radius_worst             True
# texture_worst           False
# perimeter_worst          True
# area_worst              False
# compactness_worst       False
# concavity_worst         False
# concave points_worst    False
# symmetry_worst          False
# Name: radius_mean, dtype: bool

# %%
x = x.drop(['perimeter_mean','radius_worst','perimeter_worst'], axis=1)
x.shape
# Out:
# (569, 15)
